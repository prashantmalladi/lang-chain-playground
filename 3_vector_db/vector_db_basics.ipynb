# %%
import chromadb

client = chromadb.Client()

# %%
collection = client.create_collection("news_articles")

# %%
collection.add(
    ids=["id1", "id2", "id3", "id4"],
    documents=[
        "Apple is leading in a smart phone game with iPhone sales up by 35%",
        "Tesla booked a minor profit of 1 billion $ in Q2",
        "Apples are high in fiber, vitamin C, and various antioxidants",
        "SpaceX got NASA contract worth 10 billion $",
    ]
)
# Out:
# /Users/pmalladi/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz: 100%|██████████| 79.3M/79.3M [00:06<00:00, 12.0MiB/s]

# %%
data = collection.get(
    include=["documents", "embeddings", "metadatas"]
)

#print embedding
for i, emb in enumerate(data["embeddings"]):
    print(f"\n Document {i + 1}")
    print("Text", data["documents"][i])
    print("Embedding length", len(emb))
    print("First 10 values", emb[:10])
# Out:
#  Document 1
# Text Apple is leading in a smart phone game with iPhone sales up by 35%
# Embedding length 384
# First 10 values [ 0.03640452  0.01021046  0.08642431 -0.12735224 -0.01895926  0.00309625
#   0.01671756  0.05566166  0.02376828  0.11325458]
#
#  Document 2
# Text Tesla booked a minor profit of 1 billion $ in Q2
# Embedding length 384
# First 10 values [ 0.03228297  0.08888534  0.02695833  0.07444266 -0.0677371  -0.03529561
#  -0.02407435  0.1016631   0.02283023  0.02386426]
#
#  Document 3
# Text Apples are high in fiber, vitamin C, and various antioxidants
# Embedding length 384
# First 10 values [ 0.0451243  -0.03145006  0.01100097  0.08058898  0.00119942  0.02187004
#  -0.00926966 -0.01325602  0.0042518   0.02350498]
#
#  Document 4
# Text SpaceX got NASA contract worth 10 billion $
# Embedding length 384
# First 10 values [-0.02309862  0.03526219  0.06101779 -0.02734391 -0.08042097 -0.02970155
#   0.07421497  0.05592683  0.02907897  0.07048376]

# %%
collection.query(
    query_texts="This is a query regarding elon musk",
    n_results=2
)
# Out:
# {'ids': [['id2', 'id4']],
#  'embeddings': None,
#  'documents': [['Tesla booked a minor profit of 1 billion $ in Q2',
#    'SpaceX got NASA contract worth 10 billion $']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[None, None]],
#  'distances': [[1.4568790197372437, 1.5213043689727783]]}
